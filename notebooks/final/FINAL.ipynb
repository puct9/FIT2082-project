# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.ticker import PercentFormatter
from scipy.stats import kde
from tqdm import tqdm

from research.datasets import AutoLoadedDataset
from research.evaluator import evaluate, stats_to_df
from research.regression import LinearFitSKL, FCNN

# %%
if not os.path.exists('export'):
    os.mkdir('export')
if not os.path.exists('export/eps'):
    os.mkdir('export/eps')

plt.rcParams.update({
    "savefig.facecolor": (1, 1, 1, 1),
    "figure.figsize": (7, 4),
})

def save(fname):
    plt.savefig(f'export/lin-{fname}', dpi=300)
    plt.savefig(f'export/eps/lin-{fname}.eps', dpi=1000, format='eps')

# %%
loaded = AutoLoadedDataset.load(seed=0, search_path='datasets/auto')
# Out:
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\17_lmpavw.arff
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\52_svmguide1.arff
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\53_fourclass_scale.arff
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\58_sarcasm_detection.arff
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\77_WorkersCompensation.arff
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\78_shill-bidding.arff
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\79_art_daily_nojump3.arff
# Unable to load C:\Users\Luke Yang G1\Documents\C3001\Y2\S2\FIT2082\project\datasets/auto\80_art_daily_small_noise2.arff
# Loaded 74 datasets

# %%
RESULTS = {}
for name, dataset in tqdm(loaded.items()):
    eval_stats = evaluate(dataset, LinearFitSKL, retrain_on_filtered=False)
    RESULTS[name] = stats_to_df(
        eval_stats,
        [
            'target_coverage',
            'expected_coverage',
            'coverage',
            'mse_expected',
            'mse_filtered',
            'mse_prop_base',
            'comparison_loss',
        ],
        name
    )
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [02:26<00:00,  1.97s/it]

# %%
data = pd.concat(RESULTS.values(), ignore_index=True)
data
# Out:
#             dataset  target_coverage  expected_coverage  coverage  \
# 0          0_kin8nm              0.1           0.205858  0.203907
# 1          0_kin8nm              0.2           0.205858  0.203907
# 2          0_kin8nm              0.3           0.315704  0.310134
# 3          0_kin8nm              0.4           0.445281  0.442308
# 4          0_kin8nm              0.5           0.530309  0.522589
# ..              ...              ...                ...       ...
# 735  9_wine_quality              0.6           0.673763  0.662818
# 736  9_wine_quality              0.7           0.800718  0.809084
# 737  9_wine_quality              0.8           0.800718  0.809084
# 738  9_wine_quality              0.9           0.929726  0.931486
# 739  9_wine_quality              1.0           1.000000  1.000000
#
#      mse_expected  mse_filtered  mse_prop_base  comparison_loss
# 0        0.017611      0.023148       0.569779         0.020315
# 1        0.017611      0.023148       0.569779         0.020315
# 2        0.019061      0.024004       0.590847         0.020315
# 3        0.023741      0.027338       0.672928         0.020315
# 4        0.025927      0.029807       0.733696         0.020315
# ..            ...           ...            ...              ...
# 735      0.394021      0.425985       0.819814         0.386517
# 736      0.427599      0.440004       0.846795         0.386517
# 737      0.427599      0.440004       0.846795         0.386517
# 738      0.492920      0.476783       0.917576         0.386517
# 739      0.560163      0.519612       1.000000         0.386517
#
# [740 rows x 8 columns]

# %%
stats = data.groupby('target_coverage').agg({
    'mse_prop_base': 'mean'
}).reset_index().to_numpy()

plt.plot(stats[:,0], stats[:,1], label='MSE proportion')
plt.plot([0.1, 1], [0.1, 1], 'r--', label='1:1 reference')

plt.xlabel('Target coverage')
plt.ylabel('MSE (proportion of global MSE)')
plt.ylim((0, 1.1))
plt.legend()
save('coverage-proportion reference')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
data.groupby('target_coverage').agg({
    'mse_prop_base': 'mean'
}).reset_index().to_numpy()
# Out:
# array([[0.1       , 0.39950697],
#        [0.2       , 0.45863115],
#        [0.3       , 0.49593512],
#        [0.4       , 0.54061358],
#        [0.5       , 0.57120874],
#        [0.6       , 0.61038222],
#        [0.7       , 0.68045513],
#        [0.8       , 0.74234065],
#        [0.9       , 0.85350986],
#        [1.        , 1.        ]])

# %%
coverages = data.groupby('target_coverage').agg({
    'coverage': lambda x: list(x)
}).reset_index()['coverage']

plt.boxplot(coverages, showfliers=False)
plt.plot([1, 10], [0.1, 1], 'r--', label='1:1 reference (closer to line is better)')

plt.xlabel('Target coverage')
plt.ylabel('Actual coverage')
plt.title('Target coverage : Actual coverage')
plt.legend()
plt.xticks([*range(1, 11)], [f'{i/10}' for i in range (1, 11)])

save('coverage target-actual')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
coverages = data.groupby('target_coverage').agg({
    'expected_coverage': lambda x: list(x)
}).reset_index()['expected_coverage']

plt.boxplot(coverages, showfliers=False)
plt.plot([1, 10], [0.1, 1], 'r--', label='1:1 reference (closer to line is better)')

plt.xlabel('Target coverage')
plt.ylabel('Expected coverage')
plt.title('Target coverage : Expected coverage')
plt.legend()
plt.xticks([*range(1, 11)], [f'{i/10}' for i in range (1, 11)])

save('coverage target-expected')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
x, y = data['expected_coverage'], data['coverage']

nbins = 300
k = kde.gaussian_kde([x, y])
xi, yi = np.mgrid[0:1:nbins*1j, 0:1:nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

plt.pcolormesh(xi, yi, -np.exp(-2 * zi.reshape(xi.shape)), shading='auto')
plt.scatter(x, y, color=(1,1,1,1), s=9)

plt.ylim((0, 1))
plt.title('Expected coverage : Test coverage')
plt.xlabel('Expected coverage')
plt.ylabel('Test coverage')
save('expected-actual coverage heatmap')
plt.show()

x.corr(y)
# Out:
# 0.9964061723708724

# %%
plt.scatter(data['coverage'], data['mse_prop_base'])

plt.xlabel('Coverage')
plt.ylabel('Proportion of global MSE')
plt.show()

# %%
x, y = data['coverage'], data['mse_prop_base']
nbins = 300
k = kde.gaussian_kde([x, y])
xi, yi = np.mgrid[0:1:nbins*1j, 0:1:nbins*1j]
zi = k(np.vstack([xi.flatten(), yi.flatten()]))

plt.pcolormesh(xi, yi, -np.exp(-2 * zi.reshape(xi.shape)), shading='auto')
plt.scatter(x, y, color=(1,1,1,1), s=9)

plt.ylim((0, 1))
plt.title('Coverage : Proportion of global MSE distribution')
plt.xlabel('Coverage')
plt.ylabel('Proportion of global MSE')
save('coverage-proportion heatmap')
plt.show()

# %%
data.groupby('target_coverage').agg({
    'mse_prop_base': 'mean'
})
# Out:
#                  mse_prop_base
# target_coverage
# 0.1                   0.399507
# 0.2                   0.458631
# 0.3                   0.495935
# 0.4                   0.540614
# 0.5                   0.571209
# 0.6                   0.610382
# 0.7                   0.680455
# 0.8                   0.742341
# 0.9                   0.853510
# 1.0                   1.000000

# %%
# Ones where we did well
data[np.abs(data['mse_prop_base'] / data['coverage']) < 0.05]
# Out:
#                 dataset  target_coverage  expected_coverage  coverage  \
# 460  54_COMET_MC_SAMPLE              0.1           0.257228  0.252935
# 461  54_COMET_MC_SAMPLE              0.2           0.257228  0.252935
# 462  54_COMET_MC_SAMPLE              0.3           0.315144  0.312509
# 463  54_COMET_MC_SAMPLE              0.4           0.418704  0.414642
# 464  54_COMET_MC_SAMPLE              0.5           0.507576  0.501827
# 465  54_COMET_MC_SAMPLE              0.6           0.651929  0.649170
# 466  54_COMET_MC_SAMPLE              0.7           0.721112  0.715688
# 467  54_COMET_MC_SAMPLE              0.8           0.841610  0.834500
# 560    64_dataset_sales              0.1           0.119820  0.112689
# 610          69_Titanic              0.1           0.207477  0.185393
# 611          69_Titanic              0.2           0.207477  0.185393
# 630          70_titanic              0.1           0.207477  0.185393
# 631          70_titanic              0.2           0.207477  0.185393
# 640        71_titanic_1              0.1           0.207477  0.185393
# 641        71_titanic_1              0.2           0.207477  0.185393
# 650        72_titanic_2              0.1           0.207477  0.185393
# 651        72_titanic_2              0.2           0.207477  0.185393
# 660        73_titanic_3              0.1           0.207477  0.185393
# 661        73_titanic_3              0.2           0.207477  0.185393
#
#      mse_expected  mse_filtered  mse_prop_base  comparison_loss
# 460      0.000017      0.000017       0.000761         0.005074
# 461      0.000017      0.000017       0.000761         0.005074
# 462      0.000026      0.000026       0.001183         0.005074
# 463      0.000060      0.000059       0.002679         0.005074
# 464      0.000107      0.000107       0.004839         0.005074
# 465      0.000224      0.000227       0.010271         0.005074
# 466      0.000297      0.000298       0.013463         0.005074
# 467      0.000452      0.000451       0.020374         0.005074
# 560      0.005950      0.005782       0.004716         1.064574
# 610      0.006552      0.005620       0.007958         0.526732
# 611      0.006552      0.005620       0.007958         0.526732
# 630      0.006552      0.005620       0.007958         0.509746
# 631      0.006552      0.005620       0.007958         0.509746
# 640      0.006552      0.005620       0.007958         0.528636
# 641      0.006552      0.005620       0.007958         0.528636
# 650      0.006552      0.005620       0.007958         0.508430
# 651      0.006552      0.005620       0.007958         0.508430
# 660      0.006552      0.005620       0.007958         0.510436
# 661      0.006552      0.005620       0.007958         0.510436

# %%
# Ones where we did bad
data[(data['mse_prop_base'] / data['coverage']) > 5]
# Out:
#                   dataset  target_coverage  expected_coverage  coverage  \
# 10                10_wind              0.1           0.126489  0.135413
# 50                14_pm10              0.1           0.156146  0.105528
# 51                14_pm10              0.2           0.225914  0.170854
# 60              15_pollen              0.1           0.183196  0.178038
# 80                 18_no2              0.1           0.152824  0.115578
# 400  47_disclosure_x_bias              0.1           0.123116  0.128788
# 410                48_SWD              0.1           0.134775  0.140351
# 501       59_ilpd-numeric              0.2           0.214286  0.094421
#
#      mse_expected  mse_filtered  mse_prop_base  comparison_loss
# 10   5.439970e+00  9.698095e+00       0.904629     9.878771e+00
# 50   2.123481e+04  3.954883e+04       0.941018     3.902915e+04
# 51   2.311299e+04  4.750357e+04       1.130292     3.902915e+04
# 60   1.117391e+06  1.205528e+06       1.002341     1.320404e+06
# 80   1.934874e+04  2.934986e+04       0.815395     3.275603e+04
# 400  2.522718e+08  5.019104e+08       0.837725     6.352534e+08
# 410  1.442839e-01  3.318135e-01       0.814789     4.572974e-01
# 501  2.856849e-02  1.307205e-01       0.648291     1.918867e-01

# %%
# Success stories
data[(data['mse_prop_base'] < 0.2) & (data['coverage'] > 0.8)]
# Out:
#                 dataset  target_coverage  expected_coverage  coverage  \
# 467  54_COMET_MC_SAMPLE              0.8            0.84161    0.8345
#
#      mse_expected  mse_filtered  mse_prop_base  comparison_loss
# 467      0.000452      0.000451       0.020374         0.005074

# %%
def plot_stats(name):
    stats = RESULTS[name]

    plt.plot(stats['coverage'], stats['mse_filtered'], marker='^', label='Actual MSE')
    plt.plot(stats['coverage'], stats['mse_expected'], marker='o', label='Predicted MSE')
    plt.axhline(stats['comparison_loss'][0], linestyle='--', color='r', label='Random forest performance')

    plt.xlabel('Coverage')
    plt.ylabel('MSE')
    plt.title(f'Predicted and actual MSE for {name}')
    plt.legend()
    save(name)
    plt.show()

# %%
wines = loaded['9_wine_quality']
fitter_nn = FCNN(wines.x_train, wines.y_train, [64, 64, 64], epochs=5, device='cpu')

loss = np.square(fitter_nn.predict(wines.x_test) - np.expand_dims(wines.y_test, -1)).mean()

plt.axhline(loss, 0, 1, linestyle='--', color='g', label='Neural network MSE')

plot_stats('9_wine_quality')
# Out:
# Epoch 1: loss=0.5887
# Epoch 2: loss=0.5259
# Epoch 3: loss=0.5043
# Epoch 4: loss=0.4887
# Epoch 5: loss=0.4802
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot_stats('8_cpu_small')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot_stats('54_COMET_MC_SAMPLE')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot_stats('70_titanic')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plot_stats('14_pm10')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
mask = (data['mse_expected'] < 100) & (data['mse_filtered'] < 100)

plt.scatter(data['mse_expected'][mask], data['mse_filtered'][mask])
plt.xlabel('Expected MSE')
plt.ylabel('Actual MSE')
save('expected to actual')
plt.show()

# %%
data['coverage'].corr(data['mse_prop_base'])
# Out:
# 0.6606507922028203

# %%
plt.hist(data['mse_filtered'] / data['mse_expected'], bins=30)

plt.title('Distribution of (test MSE / predicted MSE)')
plt.xlabel('Underestimation proportion (1 is best)')
plt.ylabel('Frequency')
save('underestimation dist')
plt.show()

# %%
ratios =  data['mse_filtered'] / data['mse_expected']
ratios.mean(), ratios.std()
# Out:
# (1.2637793289223933, 0.5023739858363293)

# %%
ratios.mean() + 1.96 * ratios.std()
# Out:
# 2.2484323411615987

# %%
(ratios > 1.5).mean()
# Out:
# 0.1472972972972973
